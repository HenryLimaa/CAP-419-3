# %%
type(1)

# int
# Out:
# int

# %%
type(True)

# bool
# Out:
# bool

# %%
type(5 / 2)

# float
# Out:
# float

# %%
type(2.5)

#float
# Out:
# float

# %%
type(False)

#bool
# Out:
# bool

# %%
type(5 + 3j)

#complex
# Out:
# complex
